# %% [markdown]
# ## Seaborn
# Seaborn is a plotting library for statistical analysis it is written on matplotlib

# %%
import seaborn

# %%
seaborn.__version__
# Out:
# '0.13.2'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(
    { 'Months' : np.arange(1,13),
      'Sales'  : np.random.randint(10000,100000,12)
    }
)

# %%
df
# Out:
#     Months  Sales
# 0        1  36525
# 1        2  40789
# 2        3  24459
# 3        4  96369
# 4        5  53341
# 5        6  41614
# 6        7  26020
# 7        8  49796
# 8        9  49957
# 9       10  26489
# 10      11  67801
# 11      12  59161

# %%
df.Sales=df.Sales.map(lambda val:val*9 if val>90000 else val)

# %%
df
# Out:
#     Months   Sales
# 0        1   36525
# 1        2   40789
# 2        3   24459
# 3        4  867321
# 4        5   53341
# 5        6   41614
# 6        7   26020
# 7        8   49796
# 8        9   49957
# 9       10   26489
# 10      11   67801
# 11      12   59161

# %%
df.Sales.mean()
# Out:
# np.float64(111939.41666666667)
